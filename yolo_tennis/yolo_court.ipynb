# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
#https://www.youtube.com/watch?v=sKnPJ0CqvzY
results = model.track("https://www.youtube.com/watch?v=sKnPJ0CqvzY",tracker="bytetrack.yaml")
# Out:
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#    ---------------------------------------- 1.5/1.5 MB 13.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 2.8/2.8 MB 35.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 6.2s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# requirements: Ultralytics requirements ['pafy', 'youtube_dl==2020.12.2'] not found, attempting AutoUpdate...
# ...
#      ---------------------------------------- 1.8/1.8 MB 23.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 7.2s, installed 2 packages: ['pafy', 'youtube_dl==2020.12.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# 1/1: https://www.youtube.com/watch?v=sKnPJ0CqvzY... Success ✅ (26952 frames of shape 1920x1080 at 30.00 FPS)
#
#
# ...
